# %%
# !pip install reportlab
from reportlab.pdfgen import canvas

def create_list(dan, count):
    int(count)
    if dan == "shodan":
        start = 101
    elif dan == "nidan":
        start = 201
    elif dan == "sandan":
        start = 301
    elif dan == "yondan":
        start = 401
    elif dan == "godan":
        start = 501
    elif dan == "rokudan":
        start = 601
    elif dan == "nanadan":
        start = 701
    else:
        print("Invalid dan")
        return
    return list(range(start, start + count))
# Out:
# Collecting reportlab
#   Downloading reportlab-4.4.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab) (3.4.3)
# Downloading reportlab-4.4.4-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.1 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.4

# %% [markdown]
# #Get the details
# Input the number of candidates for each Dan grade

# %%
numbers = []
count = input("Shodans: ")
numbers.extend(create_list("shodan", int(count)))
count = input("Nidans: ")
numbers.extend(create_list("nidan", int(count)))
count = input("Sandans: ")
numbers.extend(create_list("sandan", int(count)))
count = input("Yondans: ")
numbers.extend(create_list("yondan", int(count)))
count = input("Godans: ")
numbers.extend(create_list("godan", int(count)))
count = input("Rokudans: ")
numbers.extend(create_list("rokudan", int(count)))
count = input("Nanadans: ")
numbers.extend(create_list("nanadan", int(count)))

print(numbers)
# Out:
# Shodans: 20
# Nidans: 22
# Sandans: 10
# Yondans: 3
# Godans: 10
# Rokudans: 7
# Nanadans: 4
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 401, 402, 403, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 601, 602, 603, 604, 605, 606, 607, 701, 702, 703, 704]

# %%
# !pip install reportlab
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4

def numbers_to_pdf_stickers(numbers, filename="numbers.pdf"):
    c = canvas.Canvas(filename, pagesize=A4)
    page_width, page_height = A4

    # Sticker layout: 2x2 per page
    sticker_width = page_width / 2
    sticker_height = page_height / 2

    # X,Y positions: center of each sticker
    positions = [
        (sticker_width/2, 2.9*sticker_height/2),  # Top-left
        (3*sticker_width/2, 2.9*sticker_height/2),  # Top-right
        (sticker_width/2, (sticker_height/2)-20),  # Bottom-left
        (3*sticker_width/2, (sticker_height/2)-20),  # Bottom-right
    ]

    for i, number in enumerate(numbers):
        pos_index = i % 4
        x, y = positions[pos_index]

        number_str = str(number)
        if len(number_str) != 3:
            raise ValueError("All numbers must be 3 digits")

        # First digit (top line) ~150pt
        c.setFont("Times-Roman", 160)
        c.drawCentredString(x, y + 60, number_str[0])

        # Last two digits (bottom line) ~200pt
        c.setFont("Times-Roman", 220)
        c.drawCentredString(x, y - 100, number_str[1:])

        # Start new page after 4 stickers
        if pos_index == 3:
            c.showPage()

    # Save the last page if it's not full
    if len(numbers) % 4 != 0:
        c.showPage()

    c.save()

# Example usage
numbers_to_pdf_stickers(numbers)
# Out:
# Requirement already satisfied: reportlab in /usr/local/lib/python3.12/dist-packages (4.4.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab) (3.4.3)
